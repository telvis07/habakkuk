# %% [raw]
# http://docs.python.org/2/library/collections.html#counter-objects
#
# Find the most common bibleverse/date count

# %%
import jsonlib2 as json
from glob import glob
import gzip
from pandas import DataFrame, Series
from collections import Counter

# %% [markdown]
# ### Read JSON data. Count bibleverses per date

# %%
valid_bv_set = set([line.strip() for line in open('/home/telvis/habakkuk/analysis/join_data/bibleverses.txt')])
num_days = 15

# %%
# get date, counter(bibleverse)
def get_data_from_store(dirname="/opt/habakkuk_data/", num_days=30): 
    for fn in sorted(glob("%s/*"%dirname), reverse=True)[:num_days]:
        by_date_counter = Counter()
        created_at_date = None
        for line in gzip.open(fn):
            data = json.loads(line)
            if not created_at_date:
                created_at_date = data['created_at_date']
            if data['bibleverse'] not in valid_bv_set:
                continue
            by_date_counter.update([data['bibleverse']])
        yield (created_at_date, by_date_counter)
            

# create a dictionary[date] = counter
data = dict([(created_at_date, _counter) for created_at_date, _counter in get_data_from_store(num_days=num_days)])

# %% [markdown]
# ## Generate a data frame containing all dates and the counts for the 3 'most_common' bibleverses

# %%
# create a dictionary[date] = Series(3 top bibleverses per date)
top_data = {}
for created_at_date in data:
    _counter = data[created_at_date]
    top_data[created_at_date] = Series(dict(_counter.most_common(3)))

# %%
df = DataFrame(top_data)

# %% [markdown]
# ## get the number times this verse was the max and the maximum number of references in a day

# %%
def count_valid_entries(frame):
    return frame.count()
df['count_entries'] = df.apply(count_valid_entries, axis=1)
df['max'] = df.apply(numpy.max, axis=1)
df
# Out:
#                       2014-04-29  2014-04-30  2014-05-01  2014-05-02  \
# ephesians 2:8                NaN         NaN         NaN         NaN
# hebrews 11:1                 NaN         NaN         NaN         NaN
# hebrews 13:16                NaN         NaN         NaN         NaN
# i_corinthians 13:4           NaN         NaN         NaN         NaN
# i_peter 5:7                  NaN         NaN          15         NaN
# i_thessalonians 5:15         NaN         NaN         NaN         NaN
# ii_chronicles 15:7           NaN         NaN         NaN         NaN
# ii_samuel 7:22               NaN         NaN         NaN         NaN
# isaiah 32:17                 NaN         NaN         NaN         NaN
# james 1:19                   NaN         NaN         NaN         NaN
# john 13:7                    NaN          44          48          47
# john 14:6                    NaN          14         NaN          12
# john 15:13                   NaN         NaN         NaN         NaN
# john 16:24                   NaN         NaN         NaN         NaN
# luke 6:27                    NaN         NaN         NaN         NaN
# matthew 11:28                NaN         NaN         NaN         NaN
# matthew 21:22                 18         NaN         NaN         NaN
# matthew 5:8                  NaN         NaN         NaN         NaN
# philippians 2:13             NaN          16         NaN         NaN
# philippians 4:13             NaN         NaN          14         NaN
# proverbs 12:11               NaN         NaN         NaN         NaN
# proverbs 17:28               NaN         NaN         NaN          19
# proverbs 3:5                 NaN         NaN         NaN         NaN
# psalm 121:1                  NaN         NaN         NaN         NaN
# psalm 31:24                  NaN         NaN         NaN         NaN
# psalm 46:5                    17         NaN         NaN         NaN
# revelation 1:8               NaN         NaN         NaN         NaN
# romans 12:12                 NaN         NaN         NaN         NaN
# romans 15:7                   17         NaN         NaN         NaN
#
#                       2014-05-03  2014-05-04  2014-05-05  2014-05-06  \
# ephesians 2:8                NaN         NaN         NaN         NaN
# hebrews 11:1                 NaN         NaN         NaN         NaN
# hebrews 13:16                 18         NaN         NaN         NaN
# i_corinthians 13:4           NaN         NaN          14         NaN
# i_peter 5:7                  NaN         NaN         NaN         NaN
# i_thessalonians 5:15         NaN         NaN         NaN         NaN
# ii_chronicles 15:7           NaN         NaN         NaN         NaN
# ii_samuel 7:22               NaN         NaN         NaN         NaN
# isaiah 32:17                 NaN         NaN         NaN          20
# james 1:19                   NaN         NaN         NaN         NaN
# john 13:7                     64          44          36         NaN
# john 14:6                    NaN         NaN         NaN         NaN
# john 15:13                   NaN         NaN         NaN         NaN
# john 16:24                   NaN         NaN         NaN         NaN
# luke 6:27                    NaN         NaN          17         NaN
# matthew 11:28                NaN         NaN         NaN         NaN
# matthew 21:22                NaN          25         NaN         NaN
# matthew 5:8                  NaN         NaN         NaN         NaN
# philippians 2:13             NaN         NaN         NaN         NaN
# philippians 4:13             NaN         NaN         NaN          21
# proverbs 12:11               NaN         NaN         NaN         NaN
# proverbs 17:28               NaN         NaN         NaN         NaN
# proverbs 3:5                 NaN          32         NaN         NaN
# psalm 121:1                  NaN         NaN         NaN          36
# psalm 31:24                  NaN         NaN         NaN         NaN
# psalm 46:5                   NaN         NaN         NaN         NaN
# revelation 1:8               NaN         NaN         NaN         NaN
# romans 12:12                  15         NaN         NaN         NaN
# romans 15:7                  NaN         NaN         NaN         NaN
#
#                       2014-05-07  2014-05-08  2014-05-09  2014-05-10  \
# ephesians 2:8                NaN         NaN          20         NaN
# hebrews 11:1                 NaN         NaN         NaN           7
# hebrews 13:16                NaN         NaN         NaN         NaN
# i_corinthians 13:4           NaN         NaN         NaN         NaN
# i_peter 5:7                  NaN         NaN         NaN         NaN
# i_thessalonians 5:15         NaN         NaN         NaN         NaN
# ii_chronicles 15:7           NaN          23         NaN         NaN
# ii_samuel 7:22               NaN         NaN         NaN         NaN
# isaiah 32:17                 NaN         NaN         NaN         NaN
# james 1:19                   NaN         NaN         NaN         NaN
# john 13:7                     20          31          18           7
# john 14:6                    NaN         NaN         NaN         NaN
# john 15:13                   NaN         NaN         NaN         NaN
# john 16:24                   NaN          12         NaN         NaN
# luke 6:27                    NaN         NaN         NaN         NaN
# matthew 11:28                NaN         NaN         NaN         NaN
# matthew 21:22                NaN         NaN         NaN         NaN
# matthew 5:8                  NaN         NaN          18         NaN
# philippians 2:13             NaN         NaN         NaN         NaN
# philippians 4:13              19         NaN         NaN         NaN
# proverbs 12:11               NaN         NaN         NaN           7
# proverbs 17:28               NaN         NaN         NaN         NaN
# proverbs 3:5                 NaN         NaN         NaN         NaN
# psalm 121:1                  NaN         NaN         NaN         NaN
# psalm 31:24                  NaN         NaN         NaN         NaN
# psalm 46:5                   NaN         NaN         NaN         NaN
# revelation 1:8                20         NaN         NaN         NaN
# romans 12:12                 NaN         NaN         NaN         NaN
# romans 15:7                  NaN         NaN         NaN         NaN
#
#                       2014-05-12  2014-05-13  2014-05-14  count_entries  max
# ephesians 2:8                NaN         NaN         NaN              1   20
# hebrews 11:1                 NaN         NaN         NaN              1    7
# hebrews 13:16                NaN         NaN         NaN              1   18
# i_corinthians 13:4           NaN         NaN          17              2   17
# i_peter 5:7                  NaN         NaN         NaN              1   15
# i_thessalonians 5:15           9         NaN         NaN              1    9
# ii_chronicles 15:7           NaN         NaN         NaN              1   23
# ii_samuel 7:22               NaN         NaN          14              1   14
# isaiah 32:17                 NaN         NaN         NaN              1   20
# james 1:19                   NaN          24         NaN              1   24
# john 13:7                    NaN         NaN         NaN             10   64
# john 14:6                    NaN         NaN         NaN              2   14
# john 15:13                     9         NaN         NaN              1    9
# john 16:24                   NaN         NaN         NaN              1   12
# luke 6:27                      9         NaN         NaN              2   17
# matthew 11:28                NaN         NaN          16              1   16
# matthew 21:22                NaN          16         NaN              3   25
# matthew 5:8                  NaN         NaN         NaN              1   18
# philippians 2:13             NaN         NaN         NaN              1   16
# philippians 4:13             NaN         NaN         NaN              3   21
# proverbs 12:11               NaN         NaN         NaN              1    7
# proverbs 17:28               NaN         NaN         NaN              1   19
# proverbs 3:5                 NaN         NaN         NaN              1   32
# psalm 121:1                  NaN         NaN         NaN              1   36
# psalm 31:24                  NaN          14         NaN              1   14
# psalm 46:5                   NaN         NaN         NaN              1   17
# revelation 1:8               NaN         NaN         NaN              1   20
# romans 12:12                 NaN         NaN         NaN              1   15
# romans 15:7                  NaN         NaN         NaN              1   17
#
# [29 rows x 17 columns]

# %%
# normalize the max_count and max_value
top_df = df[['count_entries', 'max']]
top_df['count_entries_norm'] = top_df['count_entries']/top_df['count_entries'].max()
top_df['max_norm'] = top_df['max']/top_df['max'].max()

print top_df
# Out:
#                       count_entries  max  count_entries_norm  max_norm
# ephesians 2:8                     1   20                 0.1  0.312500
# hebrews 11:1                      1    7                 0.1  0.109375
# hebrews 13:16                     1   18                 0.1  0.281250
# i_corinthians 13:4                2   17                 0.2  0.265625
# i_peter 5:7                       1   15                 0.1  0.234375
# i_thessalonians 5:15              1    9                 0.1  0.140625
# ii_chronicles 15:7                1   23                 0.1  0.359375
# ii_samuel 7:22                    1   14                 0.1  0.218750
# isaiah 32:17                      1   20                 0.1  0.312500
# james 1:19                        1   24                 0.1  0.375000
# john 13:7                        10   64                 1.0  1.000000
# john 14:6                         2   14                 0.2  0.218750
# john 15:13                        1    9                 0.1  0.140625
# john 16:24                        1   12                 0.1  0.187500
# luke 6:27                         2   17                 0.2  0.265625
# matthew 11:28                     1   16                 0.1  0.250000
# matthew 21:22                     3   25                 0.3  0.390625
# matthew 5:8                       1   18                 0.1  0.281250
# philippians 2:13                  1   16                 0.1  0.250000
# philippians 4:13                  3   21                 0.3  0.328125
# proverbs 12:11                    1    7                 0.1  0.109375
# proverbs 17:28                    1   19                 0.1  0.296875
# proverbs 3:5                      1   32                 0.1  0.500000
# psalm 121:1                       1   36                 0.1  0.562500
# psalm 31:24                       1   14                 0.1  0.218750
# psalm 46:5                        1   17                 0.1  0.265625
# revelation 1:8                    1   20                 0.1  0.312500
# romans 12:12                      1   15                 0.1  0.234375
# romans 15:7                       1   17                 0.1  0.265625
#
# [29 rows x 4 columns]

# %% [markdown]
# ## Now lets plot the Number of Days vs Maximum Number of Tweets

# %%
# %matplotlib inline
from mpltools import style
mpl.rcParams['figure.figsize'] = (15.0, 8.0)

# plot the entries
fig, ax = plt.subplots()
ax.scatter(top_df['count_entries'], top_df['max'])
ax.set_title("Date by Popularity")
ax.set_xlabel("Number of Days in Top 3")
ax.set_ylabel("Maximum Number of Tweets in a Day")
for i, bibleverse in enumerate(top_df.index):
    # add bibleverse label to data point
    ax.annotate(bibleverse, (top_df['count_entries'][bibleverse], top_df['max'][bibleverse]))

# %%
# only show data for this scripture
# df.ix["isaiah 53:5"].dropna()

# %% [markdown]
# ### Next, perform kmeans clustering.

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=4)
kmeans.fit_predict(top_df[['count_entries_norm', 'max_norm']])
# Out:
# array([0, 2, 0, 0, 2, 2, 0, 2, 0, 0, 1, 2, 2, 2, 0, 2, 0, 0, 2, 0, 2, 0, 3,
#        3, 2, 2, 0, 2, 2], dtype=int32)

# %%
print kmeans.labels_
print kmeans.cluster_centers_
# Out:
# [0 2 0 0 2 2 0 2 0 0 1 2 2 2 0 2 0 0 2 0 2 0 3 3 2 2 0 2 2]
# [[ 0.15        0.31510417]
#  [ 1.          1.        ]
#  [ 0.10714286  0.203125  ]
#  [ 0.1         0.53125   ]]

# %% [raw]
# Cluster 0 is popular encouragement scriptures
# Cluster 1 is religious holiday scriptures
# Cluster 2 is most popular encouragement scriptures
# Cluster 3 is maven or spammer tweeted a bibleverse

# %%
# create separate lists by cluster label
from collections import defaultdict
import json
clusters = defaultdict(list)
for i, label in enumerate(kmeans.labels_):
    bv = top_df.index[i]
    clusters[label].append(bv)
    
for label in clusters:
    print "Cluster",label, json.dumps(clusters[label])
    print top_df.ix[clusters[label]][["count_entries", "max"]]
    #print [bv for bv in top_df.index[clusters[label]]]
# Out:
# Cluster 0 ["ephesians 2:8", "hebrews 13:16", "i_corinthians 13:4", "ii_chronicles 15:7", "isaiah 32:17", "james 1:19", "luke 6:27", "matthew 21:22", "matthew 5:8", "philippians 4:13", "proverbs 17:28", "revelation 1:8"]
#                     count_entries  max
# ephesians 2:8                   1   20
# hebrews 13:16                   1   18
# i_corinthians 13:4              2   17
# ii_chronicles 15:7              1   23
# isaiah 32:17                    1   20
# james 1:19                      1   24
# luke 6:27                       2   17
# matthew 21:22                   3   25
# matthew 5:8                     1   18
# philippians 4:13                3   21
# proverbs 17:28                  1   19
# revelation 1:8                  1   20
#
# [12 rows x 2 columns]
# Cluster 1 ["john 13:7"]
#            count_entries  max
# john 13:7             10   64
#
# [1 rows x 2 columns]
# Cluster 2 ["hebrews 11:1", "i_peter 5:7", "i_thessalonians 5:15", "ii_samuel 7:22", "john 14:6", "john 15:13", "john 16:24", "matthew 11:28", "philippians 2:13", "proverbs 12:11", "psalm 31:24", "psalm 46:5", "romans 12:12", "romans 15:7"]
#                       count_entries  max
# hebrews 11:1                      1    7
# i_peter 5:7                       1   15
# i_thessalonians 5:15              1    9
# ii_samuel 7:22                    1   14
# john 14:6                         2   14
# john 15:13                        1    9
# john 16:24                        1   12
# matthew 11:28                     1   16
# philippians 2:13                  1   16
# proverbs 12:11                    1    7
# psalm 31:24                       1   14
# psalm 46:5                        1   17
# romans 12:12                      1   15
# romans 15:7                       1   17
#
# [14 rows x 2 columns]
# Cluster 3 ["proverbs 3:5", "psalm 121:1"]
#               count_entries  max
# proverbs 3:5              1   32
# psalm 121:1               1   36
#
# [2 rows x 2 columns]

# %%
# %matplotlib inline
from mpltools import style
mpl.rcParams['figure.figsize'] = (15.0, 8.0)

# plot the entries
fig, ax = plt.subplots()
#for i, color in [(0,'b'), (1, 'r'), (2, 'y')]: 
#    ax.scatter(top_df.ix[clusters[i]]["count_entries"], top_df.ix[clusters[i]]["max"], c=color)
colors = dict([(0,'b'), (1, 'r'), (2, 'y'), (3, 'g')])
color = [colors[label] for label in kmeans.labels_]
total = len(kmeans.labels_)
sizes = np.array([1+log(total/len(clusters[label])) for label in kmeans.labels_]) * 100

ax.scatter(top_df["count_entries"], top_df["max"], c=color, s=sizes)
ax.set_title("clusters of Popular Scriptures by Frequency and Number of Tweets")
ax.set_xlabel("Number of Days in Top 3")
ax.set_ylabel("Maximum Number of Tweets in a Day")


#for i, bibleverse in enumerate(top_df.index):
#    # add bibleverse label to data point
#    ax.annotate(bibleverse, (top_df['count_entries'][bibleverse], top_df['max'][bibleverse]))

# %%
# next... predict what scriptures will be popular tomorrow!
# common terms query for each cluster
