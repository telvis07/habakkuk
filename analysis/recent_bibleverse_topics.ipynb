# %%
# %matplotlib inline

import jsonlib2 as json
from glob import glob
import gzip
from pandas import DataFrame, Series
from collections import Counter
from collections import defaultdict
from sklearn.cluster import KMeans
import json
from mpltools import style

# %%
# get date, counter(bibleverse)
def get_data_from_store(dirname="/opt/habakkuk_data/", num_days=30, valid_bv_set=set()): 
    for fn in sorted(glob("%s/*"%dirname), reverse=True)[:num_days]:
        by_date_counter = Counter()
        created_at_date = None
        for line in gzip.open(fn):
            data = json.loads(line)
            if not created_at_date:
                created_at_date = data['created_at_date']
            if data['bibleverse'] not in valid_bv_set:
                continue
            by_date_counter.update([data['bibleverse']])
        yield (created_at_date, by_date_counter)

# %%
def get_most_common_df(data, num=3):
    # create a dictionary[date] = Series(3 top bibleverses per date)
    top_data = {}
    for created_at_date in data:
        _counter = data[created_at_date]
        top_data[created_at_date] = Series(dict(_counter.most_common(num)))
    return DataFrame(top_data)

# %%
def count_valid_entries(frame):
    return frame.count()

# %%
def get_count_features_df(df):
    # get bv counts and max counts
    df['count_entries'] = df.apply(count_valid_entries, axis=1)
    df['max'] = df.apply(numpy.max, axis=1)
    
    # get data frame with top info
    # normalize the max_count and max_value
    top_df = df[['count_entries', 'max']]
    top_df['count_entries_norm'] = top_df['count_entries']/top_df['count_entries'].max()
    top_df['max_norm'] = top_df['max']/top_df['max'].max()
    # return top_df[['count_entries_norm', 'max_norm']]
    return top_df

# %%
def build_clusters(df, n_clusters=4):
    kmeans = KMeans(n_clusters=n_clusters)
    kmeans.fit_predict(df[['count_entries_norm', 'max_norm']])
    cluster_data = {}
    cluster_data['labels'] = kmeans.labels_
    cluster_data['cluster_centers'] = kmeans.cluster_centers_
    clusters = defaultdict(list)
    for i, label in enumerate(kmeans.labels_):
        bv = df.index[i]
        clusters[label].append(bv)
    cluster_data['clusters'] = clusters
    return cluster_data

# %%
def main():
    valid_bv_set = set([line.strip() for line in open('/home/telvis/habakkuk/analysis/join_data/bibleverses.txt')])
    num_days = 15
    # create a dictionary[date] = counter
    data = []
    for created_at_date, _counter in get_data_from_store(num_days=num_days, valid_bv_set=valid_bv_set):
        data.append((created_at_date, _counter))
    data = dict(data)
    
    # filter for most common bibleverses, returns a DataFrame
    df = get_most_common_df(data, num=3)
    
    # get bv counts and max counts
    top_df = get_count_features_df(df)
    print top_df
    
    # perform clustering
    cluster_data = build_clusters(top_df, n_clusters=6)
    return df, cluster_data

# %%
df, cluster_data = main()
# Out:
#                     count_entries  max  count_entries_norm  max_norm
# acts 2:1                        1    9                 0.2  0.191489
# ecclesiastes 4:12               1   13                 0.2  0.276596
# ephesians 2:4                   1   13                 0.2  0.276596
# i_corinthians 13:4              1   21                 0.2  0.446809
# i_corinthians 6:19              1   11                 0.2  0.234043
# i_kings 20:14                   1   13                 0.2  0.276596
# i_peter 5:7                     3   16                 0.6  0.340426
# isaiah 41:10                    1   19                 0.2  0.404255
# james 4:7                       1   13                 0.2  0.276596
# jeremiah 31:3                   1   13                 0.2  0.276596
# john 13:7                       5   47                 1.0  1.000000
# john 14:6                       1    9                 0.2  0.191489
# john 1:5                        1   21                 0.2  0.446809
# mark 11:22                      1   13                 0.2  0.276596
# mark 8:36                       1   16                 0.2  0.340426
# matthew 19:26                   2   15                 0.4  0.319149
# matthew 21:22                   2   19                 0.4  0.404255
# matthew 22:37                   2   13                 0.4  0.276596
# matthew 6:33                    1   12                 0.2  0.255319
# matthew 7:13                    2   11                 0.4  0.234043
# philippians 4:13                5   18                 1.0  0.382979
# proverbs 11:25                  1   13                 0.2  0.276596
# proverbs 16:3                   1   16                 0.2  0.340426
# proverbs 21:21                  1   28                 0.2  0.595745
# proverbs 27:2                   1   12                 0.2  0.255319
# psalm 103:13                    1   15                 0.2  0.319149
# psalm 46:10                     1   14                 0.2  0.297872
# psalm 56:3                      1   14                 0.2  0.297872
# psalm 91:1                      1   15                 0.2  0.319149
# romans 8:28                     1   12                 0.2  0.255319
# romans 8:31                     1   19                 0.2  0.404255
#
# [31 rows x 4 columns]

# %%
def print_clusters(df, clusters):
    for label in clusters:
        print "Cluster",label, json.dumps(clusters[label])
        print df.ix[clusters[label]][["count_entries", "max"]]
        print
        #print [bv for bv in top_df.index[clusters[label]]]

# %%
#display clusters
print_clusters(df, cluster_data['clusters'])
# Out:
# Cluster 0 ["acts 2:1", "ecclesiastes 4:12", "ephesians 2:4", "i_corinthians 6:19", "i_kings 20:14", "james 4:7", "jeremiah 31:3", "john 14:6", "mark 11:22", "mark 8:36", "matthew 6:33", "proverbs 11:25", "proverbs 16:3", "proverbs 27:2", "psalm 103:13", "psalm 46:10", "psalm 56:3", "psalm 91:1", "romans 8:28"]
#                     count_entries  max
# acts 2:1                        1    9
# ecclesiastes 4:12               1   13
# ephesians 2:4                   1   13
# i_corinthians 6:19              1   11
# i_kings 20:14                   1   13
# james 4:7                       1   13
# jeremiah 31:3                   1   13
# john 14:6                       1    9
# mark 11:22                      1   13
# mark 8:36                       1   16
# matthew 6:33                    1   12
# proverbs 11:25                  1   13
# proverbs 16:3                   1   16
# proverbs 27:2                   1   12
# psalm 103:13                    1   15
# psalm 46:10                     1   14
# psalm 56:3                      1   14
# psalm 91:1                      1   15
# romans 8:28                     1   12
#
# [19 rows x 2 columns]
#
# Cluster 1 ["philippians 4:13"]
#                   count_entries  max
# philippians 4:13              5   18
#
# [1 rows x 2 columns]
#
# Cluster 2 ["i_peter 5:7"]
#              count_entries  max
# i_peter 5:7              3   16
#
# [1 rows x 2 columns]
#
# Cluster 3 ["matthew 19:26", "matthew 21:22", "matthew 22:37", "matthew 7:13"]
#                count_entries  max
# matthew 19:26              2   15
# matthew 21:22              2   19
# matthew 22:37              2   13
# matthew 7:13               2   11
#
# [4 rows x 2 columns]
#
# Cluster 4 ["john 13:7"]
#            count_entries  max
# john 13:7              5   47
#
# [1 rows x 2 columns]
#
# Cluster 5 ["i_corinthians 13:4", "isaiah 41:10", "john 1:5", "proverbs 21:21", "romans 8:31"]
#                     count_entries  max
# i_corinthians 13:4              1   21
# isaiah 41:10                    1   19
# john 1:5                        1   21
# proverbs 21:21                  1   28
# romans 8:31                     1   19
#
# [5 rows x 2 columns]

# %%
def plot_clusters(df, clusters, labels):
    mpl.rcParams['figure.figsize'] = (15.0, 8.0)
    
#     # plot all entries
#     fig, ax = plt.subplots()
#     ax.scatter(df['count_entries'], df['max'])
#     ax.set_title("Date by Popularity")
#     ax.set_xlabel("Number of Days in Top 3")
#     ax.set_ylabel("Maximum Number of Tweets in a Day")
#     for i, bibleverse in enumerate(df.index):
#         # add bibleverse label to data point
#         ax.annotate(bibleverse, (df['count_entries'][bibleverse], df['max'][bibleverse]))

    # plot color coded by cluster
    fig, ax = plt.subplots()
    colors = dict([(0,'b'), (1, 'r'), (2, 'y'), (3, 'g'), ])
    
    color = [colors.get(label,'black') for label in labels]

    total = len(labels)
    sizes = np.array([1+log(total/len(clusters[label])) for label in labels]) * 100
    
    ax.scatter(df["count_entries"], df["max"], c=color, s=sizes)
    ax.set_title("clusters of Popular Scriptures by Frequency and Number of Tweets")
    ax.set_xlabel("Number of Days in Top 3")
    ax.set_ylabel("Maximum Number of Tweets in a Day")
    
    for i, bibleverse in enumerate(df.index):
        # add bibleverse label to data point
        ax.annotate(bibleverse, (df['count_entries'][bibleverse], df['max'][bibleverse]))

# %%
# plot_clusters
plot_clusters(df, cluster_data['clusters'], cluster_data['labels'])

# %%
from pyes.query import MatchAllQuery, FilteredQuery, BoolQuery, MatchQuery, TextQuery
from pyes.filters import RangeFilter, TermFilter, QueryFilter, ANDFilter
from pyes.utils import ESRange, ESRangeOp 
import re
from datetime import datetime, timedelta

from sklearn import decomposition
import time
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

def topic_extraction(corpus, bv_tokens, n_features = 5000, n_top_words = 100, n_topics = 1):
    n_samples = len(corpus)
        
    # vectorize the tweet text using the most common word
    # frequency with TF-IDF weighting (without the top 5% stop words)
    vectorizer = TfidfVectorizer(max_features=n_features, 
                                 ngram_range=(1,2)
                                 )
    stoplist = ['retweet', 'rt', 'http']
    # print bv_tokens
    vectorizer.set_params(stop_words=set(list(ENGLISH_STOP_WORDS)+stoplist+bv_tokens))
    # tfidf = vectorizer.fit_transform(corpus)
    counts = vectorizer.fit_transform(corpus)
    # what's the diff between tfidf transformer.
    tfidf = TfidfTransformer().fit_transform(counts)
    feature_names = vectorizer.get_feature_names()
    print "num 'features' from tfidf vectorizer",len(feature_names)
    
    # Fit the NMF model
    print "Fitting the NMF model on with n_samples=%d and n_features=%d..."\
      % (n_samples, n_features)
    try:
        nmf = decomposition.NMF(n_components=n_topics, random_state=42).fit(tfidf)
    except:
        print "Failed to cluster"
        return []
    
    cluster_topics = []
    for topic_idx, topic in enumerate(nmf.components_):
        cluster_topics.append([feature_names[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]])

    return cluster_topics

def get_text_from_es(conn, bibleverse, start, ts_field='created_at_date'):
    q = MatchAllQuery()
    filters = []
    filters.append(RangeFilter(qrange=ESRangeOp(field=ts_field, op1='gte',value1=start)))
    filters.append(TermFilter(field="bibleverse",value=bibleverse))
    q = FilteredQuery(MatchAllQuery(), ANDFilter(filters))
    q = q.search(size=20)
    resultset = conn.search(indices=["habakkuk-all"], doc_types=["habakkuk"], query=q, size=20)
    # print "Total results %s %s docs"%(bibleverse, resultset.total)
    res = list()
    for r in resultset:
        t = re.sub("[@#]\w+(?:$|\W)","", r['text'])
        res.append(t)
    return res

def print_topics(bv_set):
    bv_tokens = []
    [bv_tokens.extend(bv.replace(":"," ").split()) for bv in bv_set]
    from pyes import ES

    
    # get es conn
    conn = ES('192.168.117.4:9201')
    ts_field='created_at_date'
    start = datetime.now() + timedelta(days=-15)
    start = start.strftime("%Y-%m-%d")
    
    corpus = []
    for bv in bv_set:
        ret = get_text_from_es(conn, bv, start)
        corpus.append(" ".join(ret))
        # print len(" ".join(ret))
        
    topics = topic_extraction(corpus, bv_tokens)
    if topics:
        print "topic[0]",topics[0][:10]

# %%
for cluster in cluster_data['clusters']:
    print "##Cluster",cluster
    print_topics(cluster_data['clusters'][cluster])
    print "\n"
# Out:
# ##Cluster 0
# num 'features' from tfidf vectorizer
#  996
# Fitting the NMF model on with n_samples=19 and n_features=5000...
# topic[0]
#  [u'things', u'good', u'know', u'good love', u'know god', u'exalted', u'love', u'god', u'know things', u'work good']
#
#
# ##Cluster 1
# num 'features' from tfidf vectorizer 31
# Fitting the NMF model on with n_samples=1 and n_features=5000...
# Failed to cluster
#
#
# ##Cluster 2
# num 'features' from tfidf vectorizer 21
# Fitting the NMF model on with n_samples=1 and n_features=5000...
# topic[0] [u'anxiety', u'anxiety cares', u'cares', u'cast anxiety', u'cast', u'peter', u'cares peter', u'worries cast', u'worries', u'cares 1peter']
#
#
# ##Cluster 3
# num 'features' from tfidf vectorizer 361
# Fitting the NMF model on with n_samples=4 and n_features=5000...
# topic[0]
#  [u'things', u'possible', u'things possible', u'god things', u'love', u'14', u'god', u'gate', u'impossible', u'impossible god']
#
#
# ##Cluster 4
# num 'features' from tfidf vectorizer 39
# Fitting the NMF model on with n_samples=1 and n_features=5000...
# topic[0] [u'message', u'pass', u'pass message', u'yywzx8dkxw', u'message yywzx8dkxw', u'yywzx8dkxw pass', u'doing', u'understand', u'yywzx8dkxw realize', u'jesus replied']
#
#
# ##Cluster 5
# num 'features' from tfidf vectorizer 394
# Fitting the NMF model on with n_samples=5 and n_features=5000...
# topic[0]
#  [u'god', u'dismayed', u'say', u'shall', u'shall say', u'things', u'things god', u'don', u'fear', u'dismayed god']
