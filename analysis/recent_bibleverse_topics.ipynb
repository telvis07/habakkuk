# %%
# %matplotlib inline

import jsonlib2 as json
from glob import glob
import gzip
from pandas import DataFrame, Series
from collections import Counter
from collections import defaultdict
from sklearn.cluster import KMeans
import json
from mpltools import style
# Out:
# /home/telvis/anaconda/lib/python2.7/site-packages/configobj.py:145: DeprecationWarning: The compiler package is deprecated and removed in Python 3.x.
#   import compiler

# %%
# get date, counter(bibleverse)
def get_data_from_store(dirname="/opt/habakkuk_data/", num_days=30, valid_bv_set=set()): 
    for fn in sorted(glob("%s/*"%dirname), reverse=True)[:num_days]:
        by_date_counter = Counter()
        created_at_date = None
        for line in gzip.open(fn):
            data = json.loads(line)
            if not created_at_date:
                created_at_date = data['created_at_date']
            if data['bibleverse'] not in valid_bv_set:
                continue
            by_date_counter.update([data['bibleverse']])
        yield (created_at_date, by_date_counter)

# %%
def get_most_common_df(data, num=3):
    # create a dictionary[date] = Series(3 top bibleverses per date)
    top_data = {}
    for created_at_date in data:
        _counter = data[created_at_date]
        top_data[created_at_date] = Series(dict(_counter.most_common(num)))
    return DataFrame(top_data)

# %%
def count_valid_entries(frame):
    return frame.count()

# %%
def get_count_features_df(df):
    # get bv counts and max counts
    df['count_entries'] = df.apply(count_valid_entries, axis=1)
    df['max'] = df.apply(numpy.max, axis=1)
    
    # get data frame with top info
    # normalize the max_count and max_value
    top_df = df[['count_entries', 'max']]
    top_df['count_entries_norm'] = top_df['count_entries']/top_df['count_entries'].max()
    top_df['max_norm'] = top_df['max']/top_df['max'].max()
    # return top_df[['count_entries_norm', 'max_norm']]
    return top_df

# %%
def build_clusters(df, n_clusters=4):
    kmeans = KMeans(n_clusters=n_clusters)
    kmeans.fit_predict(df[['count_entries_norm', 'max_norm']])
    cluster_data = {}
    cluster_data['labels'] = kmeans.labels_
    cluster_data['cluster_centers'] = kmeans.cluster_centers_
    clusters = defaultdict(list)
    for i, label in enumerate(kmeans.labels_):
        bv = df.index[i]
        clusters[label].append(bv)
    cluster_data['clusters'] = clusters
    return cluster_data

# %%
def main(top_n=3, n_clusters=6, num_days=15):
    valid_bv_set = set([line.strip() for line in open('/home/telvis/habakkuk/analysis/join_data/bibleverses.txt')])
    # create a dictionary[date] = counter
    data = []
    for created_at_date, _counter in get_data_from_store(num_days=num_days, valid_bv_set=valid_bv_set):
        data.append((created_at_date, _counter))
    data = dict(data)
    
    # filter for most common bibleverses, returns a DataFrame
    df = get_most_common_df(data, num=top_n)
    
    # get bv counts and max counts
    top_df = get_count_features_df(df)
    #print top_df
    
    # perform clustering
    cluster_data = build_clusters(top_df, n_clusters=n_clusters)
    return df, cluster_data

# %%
def print_clusters(df, clusters):
    for label in clusters:
        print "Cluster",label, json.dumps(clusters[label])
        print df.ix[clusters[label]][["count_entries", "max"]]
        print
        #print [bv for bv in top_df.index[clusters[label]]]

# %%
def plot_clusters(df, clusters, labels):
    mpl.rcParams['figure.figsize'] = (15.0, 8.0)
    
#     # plot all entries
#     fig, ax = plt.subplots()
#     ax.scatter(df['count_entries'], df['max'])
#     ax.set_title("Date by Popularity")
#     ax.set_xlabel("Number of Days in Top 3")
#     ax.set_ylabel("Maximum Number of Tweets in a Day")
#     for i, bibleverse in enumerate(df.index):
#         # add bibleverse label to data point
#         ax.annotate(bibleverse, (df['count_entries'][bibleverse], df['max'][bibleverse]))

    # plot color coded by cluster
    fig, ax = plt.subplots()
    colors = dict([(0,'b'), (1, 'r'), (2, 'y'), (3, 'g'), ])
    
    color = [colors.get(label,'black') for label in labels]

    total = len(labels)
    sizes = np.array([1+log(total/len(clusters[label])) for label in labels]) * 100
    
    ax.scatter(df["count_entries"], df["max"], c=color, s=sizes)
    ax.set_title("clusters of Popular Scriptures by Frequency and Number of Tweets")
    ax.set_xlabel("Number of Days in Top 3")
    ax.set_ylabel("Maximum Number of Tweets in a Day")
    
    for i, bibleverse in enumerate(df.index):
        # add bibleverse label to data point
        ax.annotate(bibleverse, (df['count_entries'][bibleverse], df['max'][bibleverse]))

# %%
from pyes.query import MatchAllQuery, FilteredQuery, BoolQuery, MatchQuery, TextQuery
from pyes.filters import RangeFilter, TermFilter, QueryFilter, ANDFilter
from pyes.utils import ESRange, ESRangeOp 
import re
from datetime import datetime, timedelta

from sklearn import decomposition
import time
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

def topic_extraction(corpus, bv_tokens, n_features = 5000, n_top_words = 100, n_topics = 1):
    n_samples = len(corpus)
        
    # vectorize the tweet text using the most common word
    # frequency with TF-IDF weighting (without the top 5% stop words)
    vectorizer = TfidfVectorizer(max_features=n_features, 
                                 ngram_range=(2,2)
                                 )
    stoplist = ['retweet', 'rt', 'http', 'things', 'christ', 'lord', 'god', 'shall', 'jesus',
                'nlt', 'kjv']
    # print bv_tokens
    vectorizer.set_params(stop_words=set(list(ENGLISH_STOP_WORDS)+stoplist+bv_tokens))
    # tfidf = vectorizer.fit_transform(corpus)
    counts = vectorizer.fit_transform(corpus)
    # what's the diff between tfidf transformer.
    tfidf = TfidfTransformer().fit_transform(counts)
    feature_names = vectorizer.get_feature_names()
    print "num 'features' from tfidf vectorizer",len(feature_names)
    
    # Fit the NMF model
    print "Fitting the NMF model on with n_samples=%d and n_features=%d..."\
      % (n_samples, n_features)
    try:
        nmf = decomposition.NMF(n_components=n_topics, random_state=42).fit(tfidf)
    except:
        print "Failed to cluster"
        return []
    
    cluster_topics = []
    for topic_idx, topic in enumerate(nmf.components_):
        cluster_topics.append([feature_names[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]])

    return cluster_topics

def get_text_from_es(conn, bibleverse, start, ts_field='created_at_date'):
    q = MatchAllQuery()
    filters = []
    filters.append(RangeFilter(qrange=ESRangeOp(field=ts_field, op1='gte',value1=start)))
    filters.append(TermFilter(field="bibleverse",value=bibleverse))
    q = FilteredQuery(MatchAllQuery(), ANDFilter(filters))
    q = q.search(size=20)
    resultset = conn.search(indices=["habakkuk-all"], doc_types=["habakkuk"], query=q, size=20)
    # print "Total results %s %s docs"%(bibleverse, resultset.total)
    res = list()
    for r in resultset:
        t = re.sub("[@#]\w+(?:$|\W)","", r['text'])
        res.append(t)
    return res

def build_corpus(bibleverses, num_days=15):
    bv_tokens = []
    [bv_tokens.extend(bv.replace(":"," ").split()) for bv in bibleverses]
    from pyes import ES

    
    # get es conn
    conn = ES('192.168.117.4:9201')
    ts_field='created_at_date'
    start = datetime.now() + timedelta(days=-num_days)
    start = start.strftime("%Y-%m-%d")
    
    corpus = []
    for bv in bibleverses:
        ret = get_text_from_es(conn, bv, start)
        corpus.append(" ".join(ret))
        # print len(" ".join(ret))
    return (bv_tokens, corpus)

# %%
top_n=3
n_clusters=4
num_days=10

df, cluster_data = main(top_n=top_n, n_clusters=n_clusters, num_days=num_days)

# %%
#display clusters
print_clusters(df, cluster_data['clusters'])
# Out:
# Cluster 0 ["galatians 5:1", "i_john 1:9", "i_thessalonians 5:18", "isaiah 12:2", "jeremiah 32:17", "mark 11:24", "matthew 19:26", "matthew 28:20", "matthew 5:44", "matthew 6:33", "matthew 6:5", "philippians 1:6", "proverbs 16:24", "proverbs 16:7", "proverbs 27:2", "psalm 33:12", "romans 6:23", "romans 8:18"]
#                       count_entries  max
# galatians 5:1                     1   18
# i_john 1:9                        1   15
# i_thessalonians 5:18              1   12
# isaiah 12:2                       1   15
# jeremiah 32:17                    1   12
# mark 11:24                        1   13
# matthew 19:26                     1   17
# matthew 28:20                     1   14
# matthew 5:44                      1   17
# matthew 6:33                      1   21
# matthew 6:5                       1   11
# philippians 1:6                   1   16
# proverbs 16:24                    1   14
# proverbs 16:7                     1   13
# proverbs 27:2                     1   17
# psalm 33:12                       1   22
# romans 6:23                       1   15
# romans 8:18                       1   19
#
# [18 rows x 2 columns]
#
# Cluster 1 ["matthew 21:22"]
#                count_entries  max
# matthew 21:22              3   25
#
# [1 rows x 2 columns]
#
# Cluster 2 ["ii_timothy 1:7", "john 14:6", "philippians 4:13"]
#                   count_entries  max
# ii_timothy 1:7                2   21
# john 14:6                     2   19
# philippians 4:13              2   13
#
# [3 rows x 2 columns]
#
# Cluster 3 ["john 13:7"]
#            count_entries  max
# john 13:7              3   49
#
# [1 rows x 2 columns]

# %%
# plot_clusters
plot_clusters(df, cluster_data['clusters'], cluster_data['labels'])

# %%
saved_cluster_data = []
for label in cluster_data['clusters']:
    print "##Cluster",label,len(cluster_data['clusters'][label])
    bv_tokens, corpus = build_corpus(cluster_data['clusters'][label], num_days=num_days)
    topics = topic_extraction(corpus, bv_tokens)
    print "Cluster",label, json.dumps(cluster_data['clusters'][label])
    print

    if topics:
        print "topic[0]",topics[0][:20]
    print "\n"
    saved_cluster_data.append({"topic" : topics[0][:20], 
                               "bibleverses":cluster_data['clusters'][label], 
                               'label':int(label),
                               'cluster_size' : len(cluster_data['clusters'][label])
                               }
                              )
# Out:
# ##Cluster 0 18
# num 'features' from tfidf vectorizer
#  632
# Fitting the NMF model on with n_samples=18 and n_features=5000...
# Cluster 0 ["galatians 5:1", "i_john 1:9", "i_thessalonians 5:18", "isaiah 12:2", "jeremiah 32:17", "mark 11:24", "matthew 19:26", "matthew 28:20", "matthew 5:44", "matthew 6:33", "matthew 6:5", "philippians 1:6", "proverbs 16:24", "proverbs 16:7", "proverbs 27:2", "psalm 33:12", "romans 6:23", "romans 8:18"]
#
# topic[0] [u'blessed nation', u'set free', u'freedom set', u'nation people', u'free enjoy', u'wants free', u'free gal', u'freedom area', u'enjoy freedom', u'happy 4th', u'vivamos en', u'en libertad', u'cristo nos', u'gal freedom', u'gal wants', u'libert\xf3 para', u'libertad gal', u'nos libert\xf3', u'que vivamos', u'para que']
#
#
# <type 'list'> <type 'list'> <type 'numpy.int32'>
# ##Cluster 1 1
# num 'features' from tfidf vectorizer 27
# Fitting the NMF model on with n_samples=1 and n_features=5000...
# Cluster 1 ["matthew 21:22"]
#
# topic[0] [u'receive mat', u'ask prayer', u'prayer faith', u'faith receive', u'pray given', u'faith pray', u'given ask', u'mat ask', u'ask ask', u'ask faith', u'boa noite', u'crerem voc\xeas', u'em ora\xe7\xe3o', u'escolhiesperar bpqkey', u'voc\xeas receber\xe3o', u'tudo que', u'mat faith', u'mateus escolhiesperar', u'noite tudo', u'ora\xe7\xe3o se']
#
#
# <type 'list'> <type 'list'> <type 'numpy.int32'>
# ##Cluster 2 3
# num 'features' from tfidf vectorizer 110
# Fitting the NMF model on with n_samples=3 and n_features=5000...
# Cluster 2 ["ii_timothy 1:7", "john 14:6", "philippians 4:13"]
#
# topic[0] [u'way truth', u'truth life', u'comes father', u'life comes', u'answered way', u'father answered', u'giving ability', u'tells giving', u'ability tells', u'gives strength', u'strengthens gives', u'said way', u'father said', u'ability strengthens', u'strength tells', u'strengthens 7yv9yohspg', u'strengthens fave', u'strength gives', u'today day', u'jesustweeters strengthens']
#
#
# <type 'list'> <type 'list'> <type 'numpy.int32'>
# ##Cluster 3 1
# num 'features' from tfidf vectorizer 13
# Fitting the NMF model on with n_samples=1 and n_features=5000...
# Cluster 3 ["john 13:7"]
#
# topic[0] [u'pass message', u'message yywzx8dkxw', u'yywzx8dkxw pass', u'yywzx8dkxw replied', u'understand doing', u'someday pass', u'replied don', u'nlvbkud4uw pass', u'message nlvbkud4uw', u'message b0n2hr4ree', u'don understand', u'doing someday', u'b0n2hr4ree pass']
#
#
# <type 'list'> <type 'list'> <type 'numpy.int32'>

# %%
# filter for clusters with more than 2 scriptures but not more than 5.
# yesterday top 10
# last 7 days top 3
# last 14 days top 2
# laster 30 days top 1

print json.dumps(saved_cluster_data, indent=2)
# Out:
# [
#   {
#     "topic": [
#       "blessed nation",
#       "set free",
#       "freedom set",
#       "nation people",
#       "free enjoy",
#       "wants free",
#       "free gal",
#       "freedom area",
#       "enjoy freedom",
#       "happy 4th",
#       "vivamos en",
#       "en libertad",
#       "cristo nos",
#       "gal freedom",
#       "gal wants",
#       "libert\u00f3 para",
#       "libertad gal",
#       "nos libert\u00f3",
#       "que vivamos",
#       "para que"
#     ],
#     "label": 0,
#     "cluster_size": 18,
#     "bibleverses": [
#       "galatians 5:1",
#       "i_john 1:9",
#       "i_thessalonians 5:18",
#       "isaiah 12:2",
#       "jeremiah 32:17",
#       "mark 11:24",
#       "matthew 19:26",
#       "matthew 28:20",
#       "matthew 5:44",
#       "matthew 6:33",
#       "matthew 6:5",
#       "philippians 1:6",
#       "proverbs 16:24",
#       "proverbs 16:7",
#       "proverbs 27:2",
#       "psalm 33:12",
#       "romans 6:23",
#       "romans 8:18"
#     ]
#   },
#   {
#     "topic": [
#       "receive mat",
#       "ask prayer",
#       "prayer faith",
#       "faith receive",
#       "pray given",
#       "faith pray",
#       "given ask",
#       "mat ask",
#       "ask ask",
#       "ask faith",
#       "boa noite",
#       "crerem voc\u00eas",
#       "em ora\u00e7\u00e3o",
#       "escolhiesperar bpqkey",
#       "voc\u00eas receber\u00e3o",
#       "tudo que",
#       "mat faith",
#       "mateus escolhiesperar",
#       "noite tudo",
#       "ora\u00e7\u00e3o se"
#     ],
#     "label": 1,
#     "cluster_size": 1,
#     "bibleverses": [
#       "matthew 21:22"
#     ]
#   },
#   {
#     "topic": [
#       "way truth",
#       "truth life",
#       "comes father",
#       "life comes",
#       "answered way",
#       "father answered",
#       "giving ability",
#       "tells giving",
#       "ability tells",
#       "gives strength",
#       "strengthens gives",
#       "said way",
#       "father said",
#       "ability strengthens",
#       "strength tells",
#       "strengthens 7yv9yohspg",
#       "strengthens fave",
#       "strength gives",
#       "today day",
#       "jesustweeters strengthens"
#     ],
#     "label": 2,
#     "cluster_size": 3,
#     "bibleverses": [
#       "ii_timothy 1:7",
#       "john 14:6",
#       "philippians 4:13"
#     ]
#   },
#   {
#     "topic": [
#       "pass message",
#       "message yywzx8dkxw",
#       "yywzx8dkxw pass",
#       "yywzx8dkxw replied",
#       "understand doing",
#       "someday pass",
#       "replied don",
#       "nlvbkud4uw pass",
#       "message nlvbkud4uw",
#       "message b0n2hr4ree",
#       "don understand",
#       "doing someday",
#       "b0n2hr4ree pass"
#     ],
#     "label": 3,
#     "cluster_size": 1,
#     "bibleverses": [
#       "john 13:7"
#     ]
#   }
# ]
